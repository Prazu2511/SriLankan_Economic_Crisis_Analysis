# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/prajwala/Downloads/economy - Data (1).csv")

# %%
data.head()
# Out:
#    Unnamed: 0                                          Item Name  \
# 0         NaN                    Agriculture-Agriculture Indices
# 1         1.0                           Agriculture Volume Index
# 2         NaN  Central Government Finance-Central Government ...
# 3         2.0  General Government Revenue - Total Tax and Non...
# 4         NaN         Central Government Finance-Debt Statistics
#
#                 Unit        Scale  1960  1961  1962  1963  1964  1965  ...  \
# 0                NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1  Percentage Change  Index Point   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2                NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3                LKR  Rs. million   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4                NaN          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#          2014        2015       2016       2017       2018       2019  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Item Name', 'Unit', 'Scale', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
data.shape
# Out:
# (12, 68)

# %%
data = data.drop(columns=['Unnamed: 0', 'Unit', 'Scale'])

# %%
data.head()
# Out:
#                                            Item Name  1960  1961  1962  1963  \
# 0                    Agriculture-Agriculture Indices   NaN   NaN   NaN   NaN
# 1                           Agriculture Volume Index   NaN   NaN   NaN   NaN
# 2  Central Government Finance-Central Government ...   NaN   NaN   NaN   NaN
# 3  General Government Revenue - Total Tax and Non...   NaN   NaN   NaN   NaN
# 4         Central Government Finance-Debt Statistics   NaN   NaN   NaN   NaN
#
#    1964  1965  1966  1967  1968  ...        2014        2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...      119.88      127.57      127.2
# 2   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN        NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...  1195206.00  1454878.00  1804250.0
# 4   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN        NaN
#
# ...

# %%
data.shape
# Out:
# (12, 65)

# %%
data_t=data.T

# %%
data_t.shape
# Out:
# (65, 12)

# %%
data_t.head()
# Out:
#                                         0                         1   \
# Item Name  Agriculture-Agriculture Indices  Agriculture Volume Index
# 1960                                   NaN                       NaN
# 1961                                   NaN                       NaN
# 1962                                   NaN                       NaN
# 1963                                   NaN                       NaN
#
#                                                           2   \
# Item Name  Central Government Finance-Central Government ...
# 1960                                                     NaN
# 1961                                                     NaN
# 1962                                                     NaN
# 1963                                                     NaN
#
#                                                           3   \
# Item Name  General Government Revenue - Total Tax and Non...
# ...

# %%
data_t.columns
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
data_t.columns = data_t.iloc[0].reset_index(drop=True)
data_t.head()
# Out:
# Item Name  Agriculture-Agriculture Indices  Agriculture Volume Index  \
# Item Name  Agriculture-Agriculture Indices  Agriculture Volume Index
# 1960                                   NaN                       NaN
# 1961                                   NaN                       NaN
# 1962                                   NaN                       NaN
# 1963                                   NaN                       NaN
#
# Item Name Central Government Finance-Central Government Revenue  \
# Item Name  Central Government Finance-Central Government ...
# 1960                                                     NaN
# 1961                                                     NaN
# 1962                                                     NaN
# 1963                                                     NaN
#
# Item Name General Government Revenue - Total Tax and Non Tax Revenue  \
# Item Name  General Government Revenue - Total Tax and Non...
# ...

# %%
data_t = data_t[1:]

# %%
data_t.head()
# Out:
# Item Name Agriculture-Agriculture Indices Agriculture Volume Index  \
# 1960                                  NaN                      NaN
# 1961                                  NaN                      NaN
# 1962                                  NaN                      NaN
# 1963                                  NaN                      NaN
# 1964                                  NaN                      NaN
#
# Item Name Central Government Finance-Central Government Revenue  \
# 1960                                                     NaN
# 1961                                                     NaN
# 1962                                                     NaN
# 1963                                                     NaN
# 1964                                                     NaN
#
# Item Name General Government Revenue - Total Tax and Non Tax Revenue  \
# 1960                                                     NaN
# ...

# %%
data_t.columns
# Out:
# Index(['Agriculture-Agriculture Indices', 'Agriculture Volume Index',
#        'Central Government Finance-Central Government Revenue',
#        'General Government Revenue - Total Tax and Non Tax Revenue',
#        'Central Government Finance-Debt Statistics',
#        'External Debt Statistics (EDS) - Outstanding Total External Debt',
#        'Imports and Exports-Imports (in USD terms)',
#        'Merchandise Imports - Total',
#        'Imports and Exports-Exports (in USD terms)',
#        'Merchandise Exports - Total', 'Tourism-Tourist Arrivals',
#        'Total Tourist Arrivals'],
#       dtype='object', name='Item Name')

# %%
data_t= data_t.drop(columns=[
        'Agriculture-Agriculture Indices',
        'Central Government Finance-Central Government Revenue',
        'Central Government Finance-Debt Statistics',
        'Imports and Exports-Imports (in USD terms)',
        'Imports and Exports-Exports (in USD terms)',
        'Tourism-Tourist Arrivals'
    ])

# %%
data_t.columns
# Out:
# Index(['Agriculture Volume Index',
#        'General Government Revenue - Total Tax and Non Tax Revenue',
#        'External Debt Statistics (EDS) - Outstanding Total External Debt',
#        'Merchandise Imports - Total', 'Merchandise Exports - Total',
#        'Total Tourist Arrivals'],
#       dtype='object', name='Item Name')

# %%
data_t.shape
# Out:
# (64, 6)

# %%
data_t.head()
# Out:
# Item Name Agriculture Volume Index  \
# 1960                           NaN
# 1961                           NaN
# 1962                           NaN
# 1963                           NaN
# 1964                           NaN
#
# Item Name General Government Revenue - Total Tax and Non Tax Revenue  \
# 1960                                                     NaN
# 1961                                                     NaN
# 1962                                                     NaN
# 1963                                                     NaN
# 1964                                                     NaN
#
# Item Name External Debt Statistics (EDS) - Outstanding Total External Debt  \
# 1960                                                     NaN
# 1961                                                     NaN
# 1962                                                     NaN
# 1963                                                     NaN
# ...

# %%
for col in data_t.columns:
    data_t[col].fillna(data_t[col].median(), inplace=True)
# Out:
# /var/folders/jh/_r_npsh108qbfhhjrzb5chjc0000gn/T/ipykernel_17694/2887022817.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_t[col].fillna(data_t[col].median(), inplace=True)
# ...

# %%
data_t.head()
# Out:
# Item Name  Agriculture Volume Index  \
# 1960                          99.56
# 1961                          99.56
# 1962                          99.56
# 1963                          99.56
# 1964                          99.56
#
# Item Name  General Government Revenue - Total Tax and Non Tax Revenue  \
# 1960                                                967862.0
# 1961                                                967862.0
# 1962                                                967862.0
# 1963                                                967862.0
# 1964                                                967862.0
#
# Item Name  External Debt Statistics (EDS) - Outstanding Total External Debt  \
# 1960                                                 46585.7
# 1961                                                 46585.7
# 1962                                                 46585.7
# 1963                                                 46585.7
# ...

# %%
data_t.tail()
# Out:
# Item Name  Agriculture Volume Index  \
# 2019                         129.00
# 2020                         129.40
# 2021                         133.30
# 2022                          99.56
# 2023                          99.56
#
# Item Name  General Government Revenue - Total Tax and Non Tax Revenue  \
# 2019                                               2026443.0
# 2020                                               1469928.0
# 2021                                               1561390.0
# 2022                                               2052977.0
# 2023                                                967862.0
#
# Item Name  External Debt Statistics (EDS) - Outstanding Total External Debt  \
# 2019                                                54811.50
# 2020                                                49211.62
# 2021                                                46585.70
# 2022                                                46585.70
# ...

# %%
data_t.columns=[ 'Agriculture' , 'Revenue','Debts', 'Imports', 'Exports', 'Tourism']

# %%
data_t.columns
# Out:
# Index(['Agriculture', 'Revenue', 'Debts', 'Imports', 'Exports', 'Tourism'], dtype='object')

# %%
data_t.head()
# Out:
#       Agriculture   Revenue    Debts  Imports  Exports   Tourism
# 1960        99.56  967862.0  46585.7    421.3    377.2  392250.0
# 1961        99.56  967862.0  46585.7    376.7    358.5  392250.0
# 1962        99.56  967862.0  46585.7    400.3    370.2  392250.0
# 1963        99.56  967862.0  46585.7    392.5    358.7  392250.0
# 1964        99.56  967862.0  46585.7    411.6    371.1  392250.0

# %%
data_x = data_t.rename_axis("Year").reset_index()

# %%
data_x.head()
# Out:
#    Year  Agriculture   Revenue    Debts  Imports  Exports   Tourism
# 0  1960        99.56  967862.0  46585.7    421.3    377.2  392250.0
# 1  1961        99.56  967862.0  46585.7    376.7    358.5  392250.0
# 2  1962        99.56  967862.0  46585.7    400.3    370.2  392250.0
# 3  1963        99.56  967862.0  46585.7    392.5    358.7  392250.0
# 4  1964        99.56  967862.0  46585.7    411.6    371.1  392250.0

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x="Year", y="Agriculture", data=data_x, marker='o')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20, 10))

# Plot "Imports" and "Exports" against "Year"
sns.lineplot(x="Year", y="Imports", data=data_x, label="Imports", marker='o')
sns.lineplot(x="Year", y="Exports", data=data_x, label="Exports", marker='o')

# Set title and labels
plt.title("Imports and Exports Over Years")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend(title="Variables")
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
sns.pairplot(data_x[['Year', 'Imports', 'Exports', 'Tourism']])
plt.show()

# %%
correlation_matrix = data_x.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
data_x.to_csv("modified_dataset.csv")
